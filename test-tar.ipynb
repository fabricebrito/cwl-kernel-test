# %% [markdown]
# # Common Workflow Language - Jupyter Notebook Kernel

# %% [markdown]
# ## [Parameter References](https://www.commonwl.org/user_guide/06-params/index.html)
#
# For parameter reference nothing change. We execute the workflow the same way.
#
# For the current examples there are some prerequired files which could be created by running the following examples:
# ```bash
# rm hello.tar # if file exists
# touch goodbye.txt
# tar -cvf hello.tar goodbye.txt
# ```

# %%
% system 
rm -f hello.tar goodbye.txt
touch goodbye.txt
tar -cvf hello.tar goodbye.txt
# Out:
# goodbye.txt

# %%
#!/usr/bin/env cwl-runner

cwlVersion: v1.0
class: CommandLineTool
baseCommand: [tar, --extract]
id: tar
inputs:
  tarfile:
    type: File
    inputBinding:
      prefix: --file
  extractfile:
    type: string
    inputBinding:
      position: 1
outputs:
  extracted_file:
    type: File
    outputBinding:
      glob: $(inputs.extractfile)
# Out:
# tool 'tar' registered

# %%
% execute tar
tarfile:
  class: File
  location: hello.tar
extractfile: goodbye.txt
# Out:
# Add data in memory
# {"extracted_file": {"location": "file:///tmp/CWLKERNEL_DATA/2bf8e9bf-b5e4-4a81-9265-4332203094ae/runtime_data/goodbye.txt", "basename": "goodbye.txt", "nameroot": "goodbye", "nameext": ".txt", "class": "File", "checksum": "sha1$da39a3ee5e6b4b0d3255bfef95601890afd80709", "size": 0, "http://commonwl.org/cwltool#generation": 0, "_produced_by": "tar", "id": "extracted_file", "result_counter": 0}}
